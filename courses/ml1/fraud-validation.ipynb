# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics
import gc

# %%
PATH = 'data/fraud-detection/'

# %% [markdown]
# # Validation Set Creation Plan
# <ol>
#     <li> Read in data sets, generating date time columns </li>
#     <li> Determine day, hours, ips of test set </li>
#     <li> Valid: Select data from day before test day, limit to hours, ips of test set </li>
#     <li> Train: Select one or two days before test set </li>
# </ol>

# %% [markdown]
# ## 1. Read in data sets, generating date time columns

# %%
# !ls data/fraud-detection/tmp/
# Out:
# df_raw.feather	test_df.feather  train_df.feather  val_idxs.npy

# %%
PATH = 'data/fraud-detection/'

# %%
dtypes = {
            'ip'            : 'uint32',
            'app'           : 'uint16',
            'device'        : 'uint16',
            'os'            : 'uint16',
            'channel'       : 'uint16',
            'is_attributed' : 'uint8',
            'click_id'      : 'uint32',
            }

# %%
test_df = pd.read_csv(f"{PATH}test.csv", parse_dates=['click_time'], dtype=dtypes, \
                      usecols=['ip','app','device','os', 'channel', 'click_time', 'click_id'])

# %%
train_df = pd.read_csv(f'{PATH}train.csv', parse_dates=['click_time'], dtype=dtypes, \
                     usecols=['ip','app','device','os', 'channel', 'click_time', 'is_attributed'])

# %%
train_df['hour'] = pd.to_datetime(train_df.click_time).dt.hour.astype('uint8')
train_df['minute'] = pd.to_datetime(train_df.click_time).dt.minute.astype('uint8')

# %%
test_df['hour'] = pd.to_datetime(test_df.click_time).dt.hour.astype('uint8')
test_df['minute'] = pd.to_datetime(test_df.click_time).dt.minute.astype('uint8')

# %%
gc.collect()
# Out:
# 154

# %%
train_df.to_feather(f'{PATH}tmp/df_raw.feather')

# %%
test_df.to_feather(f'{PATH}tmp/test_df.feather')

# %%
PATH = 'data/fraud-detection/'
train_df = pd.read_feather(f'{PATH}tmp/df_raw.feather')

# %%
test_df = pd.read_feather(f'{PATH}tmp/test_df.feather')

# %% [markdown]
# ## 2. Determine day, hours, ips of test set

# %%
len_train = len(train_df)

# %%
len_test = len(test_df)

# %%
train_df['day'] = pd.to_datetime(train_df.click_time).dt.day.astype('uint8')

# %%
test_df['day'] = pd.to_datetime(test_df.click_time).dt.day.astype('uint8')

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000):
        with pd.option_context("display.max_columns", 1000):
            display(df)

# %%
display_all(test_df.describe(include='all').transpose())
# Out:
#                   count unique                  top  freq  \
# click_id    1.87905e+07    NaN                  NaN   NaN
# ip          1.87905e+07    NaN                  NaN   NaN
# app         1.87905e+07    NaN                  NaN   NaN
# device      1.87905e+07    NaN                  NaN   NaN
# os          1.87905e+07    NaN                  NaN   NaN
# channel     1.87905e+07    NaN                  NaN   NaN
# click_time     18790469  21603  2017-11-10 09:00:10  1466
# hour        1.87905e+07    NaN                  NaN   NaN
# minute      1.87905e+07    NaN                  NaN   NaN
# day         1.87905e+07    NaN                  NaN   NaN
#
#                           first                 last         mean  \
# click_id                    NaN                  NaN  9.39523e+06
# ip                          NaN                  NaN      63069.2
# app                         NaN                  NaN      12.2148
# device                      NaN                  NaN      1.73051
# os                          NaN                  NaN      18.7331
# channel                     NaN                  NaN      264.806
# click_time  2017-11-10 04:00:00  2017-11-10 15:00:00          NaN
# hour                        NaN                  NaN      9.21995
# minute                      NaN                  NaN      29.3203
# day                         NaN                  NaN           10
#
#                     std  min          25%          50%          75%  \
# click_id    5.42434e+06    0  4.69762e+06  9.39523e+06  1.40929e+07
# ip                36886    0        31558        63936        95316
# app             11.6492    0            3           12           18
# device          25.9704    0            1            1            1
# os              11.3506    0           13           18           19
# channel         135.525    0          135          236          401
# click_time          NaN  NaN          NaN          NaN          NaN
# hour            3.75193    4            5           10           13
# minute          17.3159    0           14           29           44
# day                   0   10           10           10           10
#
#                     max
# click_id    1.87905e+07
# ip               126413
# app                 521
# device             3031
# os                  604
# channel             498
# click_time          NaN
# hour                 15
# minute               59
# day                  10

# %% [markdown]
# test hour runs from 4 through 15, day is 10

# %%
display_all(train_df.describe(include='all').transpose())
# Out:
#                      count  unique                  top  freq  \
# ip             1.84904e+08     NaN                  NaN   NaN
# app            1.84904e+08     NaN                  NaN   NaN
# device         1.84904e+08     NaN                  NaN   NaN
# os             1.84904e+08     NaN                  NaN   NaN
# channel        1.84904e+08     NaN                  NaN   NaN
# click_time       184903890  259620  2017-11-07 14:00:11  1502
# is_attributed  1.84904e+08     NaN                  NaN   NaN
# hour           1.84904e+08     NaN                  NaN   NaN
# minute         1.84904e+08     NaN                  NaN   NaN
# day            1.84904e+08     NaN                  NaN   NaN
#
#                              first                 last        mean  \
# ip                             NaN                  NaN       90876
# app                            NaN                  NaN     12.0113
# device                         NaN                  NaN     21.7233
# os                             NaN                  NaN      22.677
# channel                        NaN                  NaN     268.579
# click_time     2017-11-06 14:32:21  2017-11-09 16:00:00         NaN
# is_attributed                  NaN                  NaN  0.00247072
# hour                           NaN                  NaN     9.29878
# minute                         NaN                  NaN     29.3264
# day                            NaN                  NaN     7.86353
#
#                      std  min    25%    50%     75%     max
# ip               69527.9    1  40245  79622  118247  364778
# app              14.8052    0      3     12      15     768
# device           259.333    0      1      1       1    4227
# os               55.2528    0     13     18      19     956
# channel          129.588    0    140    258     379     500
# click_time           NaN  NaN    NaN    NaN     NaN     NaN
# is_attributed  0.0496449    0      0      0       0       1
# hour             6.17164    0      4      9      14      23
# minute            17.381    0     14     29      44      59
# day             0.889935    6      7      8       9       9

# %% [markdown]
# train day runs from 6 through 9

# %%
for day in range(6,10):
    display_all(train_df[['day', 'hour']][train_df.day == day].describe(include='uint8').transpose())
# Out:
#           count       mean       std   min   25%   50%   75%   max
# day   9308568.0   6.000000  0.000000   6.0   6.0   6.0   6.0   6.0
# hour  9308568.0  19.467074  2.852707  14.0  17.0  19.0  23.0  23.0
#            count      mean       std  min  25%  50%   75%   max
# day   59633310.0  7.000000  0.000000  7.0  7.0  7.0   7.0   7.0
# hour  59633310.0  9.209491  6.225496  0.0  4.0  9.0  14.0  23.0
#            count     mean       std  min  25%  50%   75%   max
# day   62945075.0  8.00000  0.000000  8.0  8.0  8.0   8.0   8.0
# hour  62945075.0  9.42701  6.170658  0.0  4.0  9.0  14.0  23.0
#            count      mean       std  min  25%  50%   75%   max
# day   53016937.0  9.000000  0.000000  9.0  9.0  9.0   9.0   9.0
# hour  53016937.0  7.461635  4.588471  0.0  4.0  7.0  12.0  16.0

# %% [markdown]
# So the train data runs from day 6:hour 14 continuously through day 9: hour 23

# %%
len(test_df.ip.unique())
# Out:
# 93936

# %%
len(train_df.ip.unique())
# Out:
# 277396

# %%
gc.collect()
# Out:
# 107

# %%
test_ips = test_df.ip.unique()

# %% [markdown]
# ## 3. Valid: Select data from day before test day, limit to hours, ips of test set

# %%
# note this creates a view of the dataframe, not a new dataframe
val_df = train_df[train_df.ip.isin(test_ips)][train_df.day == 9]
# Out:
# /home/zlandes/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
val_df = val_df[val_df.hour.isin(range(4,16))]

# %%
val_df.reset_index().to_feather(f'{PATH}tmp/val_df.feather')

# %%
len(val_df)
# Out:
# 32715929

# %%
val_idxs = val_df.index.values

# %%
len(val_idxs)
# Out:
# 32715929

# %%
np.save(f'{PATH}tmp/val_idxs', val_idxs)

# %%
val_idxs = np.load(f'{PATH}tmp/val_idxs.npy')

# %%
# !ls {PATH}tmp
# Out:
# df_raw.feather	test_df.feather  val_idxs.feather.npy  val_idxs.npy

# %%
val_df = val_df.copy()

# %% [markdown]
# ## 4. Train: Select one or two days before test set

# %%
train_df = train_df[train_df.day.isin([7,8])]
gc.collect()
# Out:
# 474

# %%
train_df.reset_index().to_feather(f'{PATH}tmp/train_df.feather')

# %%
train_df = pd.read_feather(f'{PATH}tmp/train_df.feather')

# %%
# sizes to sample, twice as many for train since train is twice as many days
train_sample = 10000000
val_sample = train_sample/2

# %%
len(train_df)
# Out:
# 122578385

# %%
train_df = train_df.sample(n=train_sample, random_state=42)
gc.collect()
# Out:
# 518

# %%
val_df = val_df.sample(n=val_sample, random_state=42)
gc.collect()
# Out:
# 331

# %%
train_df = train_df.drop('day', axis=1)
val_df = val_df.drop('day', axis=1)

# %%
len(val_df)
# Out:
# 5000000

# %%
train_df = train_df.append(val_df)

# %%
del val_df
gc.collect()
# Out:
# 804

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Final data subset preprocessing before feature engineering

# %%
len(val_df)
# Out:
# 32715929

# %%
del train_df
del test_df
gc.collect()
# Out:
# 1129

# %%
df = train_df.copy()
del train_df
gc.collect()
# Out:
# 228

# %%
del val_df
gc.collect()
# Out:
# 160

# %%
df = df.reset_index()

# %%
y = df['is_attributed'].values

# %%
df.drop('is_attributed', axis = 1, inplace=True)

# %%
len(df)
# Out:
# 72527535

# %%
len(y)
# Out:
# 72527535

# %%
df.head()
# Out:
#       index      ip  app  device  os  channel          click_time  hour  \
# 0  82259195   58991   12       1  26      259 2017-11-08 04:00:00     4
# 1  82259196  184626   18       1  19      121 2017-11-08 04:00:00     4
# 2  82259197  151871    3       1   9      280 2017-11-08 04:00:00     4
# 3  82259198    4180    3       1  19      424 2017-11-08 04:00:00     4
# 4  82259199  231270    9       1  15      466 2017-11-08 04:00:00     4
#
#    minute
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.drop('index', axis=1, inplace=True)

# %%
df.head(2)
# Out:
#        ip  app  device  os  channel          click_time  hour  minute
# 0   58991   12       1  26      259 2017-11-08 04:00:00     4       0
# 1  184626   18       1  19      121 2017-11-08 04:00:00     4       0

# %% [markdown]
# ## Feature Definitions

# %%
def do_skew( df, group_cols, counted, agg_name, agg_type='float32', show_max=False, show_agg=True ):
    if show_agg:
        print( "Calculating skew of ", counted, " by ", group_cols , '...' )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].skew().reset_index().rename(columns={counted:agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
def do_var( df, group_cols, counted, agg_name, agg_type='float32', show_max=False, show_agg=True ):
    if show_agg:
        print( "Calculating variance of ", counted, " by ", group_cols , '...' )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].var().reset_index().rename(columns={counted:agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
def do_count( df, group_cols, agg_name, agg_type='uint32', show_max=False, show_agg=True ):
    if show_agg:
        print( "Aggregating by ", group_cols , '...' )
    gp = df[group_cols].groupby(group_cols).size().rename(agg_name).to_frame().reset_index()
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
def do_countuniq( df, group_cols, counted, agg_name, agg_type='uint32', show_max=False, show_agg=True ):
    if show_agg:
        print( "Counting unqiue ", counted, " by ", group_cols , '...' )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].nunique().reset_index().rename(columns={counted:agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
def do_cumcount( df, group_cols, counted, agg_name, agg_type='uint32', show_max=False, show_agg=True ):
    if show_agg:
        print( "Cumulative count by ", group_cols , '...' )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].cumcount()
    df[agg_name]=gp.values
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
def do_mean( df, group_cols, counted, agg_name, agg_type='float32', show_max=False, show_agg=True ):
    if show_agg:
        print( "Calculating mean of ", counted, " by ", group_cols , '...' )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].mean().reset_index().rename(columns={counted:agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
def do_var( df, group_cols, counted, agg_name, agg_type='float32', show_max=False, show_agg=True ):
    if show_agg:
        print( "Calculating variance of ", counted, " by ", group_cols , '...' )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].var().reset_index().rename(columns={counted:agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
def do_click_shift(df, group_cols, shift_name, agg_type='float32', shift_val=-1, show_max=False, \
                   show_agg=True):
    if show_agg:
        print( "Aggregating by ", group_cols , '...' )
    #gp = 
    df[shift_name] = df[group_cols + ['click_time']].groupby(group_cols).click_time.transform(lambda x: x.diff().shift(shift_val)).dt.seconds#.rename(shift_name).to_frame().reset_index()
    #add fillna code from above here
    #df = df.merge(gp, on=group_cols, how='left')
    #del gp
    if show_max:
        print( shift_name + " max value = ", df[shift_name].max() )
    df[shift_name] = df[shift_name].astype(agg_type)
    gc.collect()
    return( df )

# %%
# creating 5 min buckets
ns5min=5*60*1000000000
df['fives'] = pd.to_datetime(((df.click_time.astype(np.int64) // ns5min + 1 ) * ns5min)).dt.minute.astype('uint8')

# %%
df.head(2)
# Out:
#        ip  app  device  os  channel          click_time  hour  minute  fives
# 0   58991   12       1  26      259 2017-11-08 04:00:00     4       0      5
# 1  184626   18       1  19      121 2017-11-08 04:00:00     4       0      5

# %%
df.tail(2)
# Out:
#               ip  app  device  os  channel          click_time  hour  minute  \
# 72527533  103239   11       1  15      173 2017-11-09 15:59:59    15      59
# 72527534   90379   18       1  17      107 2017-11-09 15:59:59    15      59
#
#           fives
# 72527533      0
# 72527534      0

# %%
train_df = df.copy()

# %%
del df
gc.collect()
# Out:
# 413

# %%
train_df = do_skew( train_df, ['ip', 'app', 'os'], 'hour', 'ip_app_os_skew_h', show_max=True ); gc.collect()
train_df = do_var( train_df, ['ip', 'app', 'os'], 'hour', 'ip_app_os_var_h', show_max=True ); gc.collect()
train_df = do_skew( train_df, ['ip', 'app', 'os', 'hour'], 'fives', 'ip_app_os_skew_f', show_max=True ); gc.collect()
train_df = do_var( train_df, ['ip', 'app', 'os', 'hour'], 'fives', 'ip_app_os_var_f', show_max=True ); gc.collect()
train_df = do_skew( train_df, ['ip', 'device', 'os'], 'hour', 'ip_dev_os_skew_h', show_max=True ); gc.collect()
train_df = do_var( train_df, ['ip', 'device', 'os'], 'hour', 'ip_dev_os_var_h', show_max=True ); gc.collect()
train_df = do_skew( train_df, ['ip', 'device', 'os', 'hour'], 'fives', 'ip_dev_os_skew_f', show_max=True ); gc.collect()
train_df = do_var( train_df, ['ip', 'device', 'os', 'hour'], 'fives', 'ip_dev_os_var_f', show_max=True ); gc.collect()
train_df = do_skew( train_df, ['ip', 'app', 'os'], 'minute', 'ip_app_os_skew_m', show_max=True ); gc.collect()
train_df = do_var( train_df, ['ip', 'app', 'os'], 'minute', 'ip_app_os_var_m', show_max=True ); gc.collect()
train_df = do_skew( train_df, ['ip', 'app', 'os', 'hour'], 'minute', 'ip_app_os_h_skew_m', show_max=True ); gc.collect()
train_df = do_var( train_df, ['ip', 'app', 'os', 'hour'], 'minute', 'ip_app_os_h_var_m', show_max=True ); gc.collect()
train_df = do_countuniq( train_df, ['ip'], 'channel', 'X0', 'uint8', show_max=True ); gc.collect()
train_df = do_cumcount( train_df, ['ip', 'device', 'os'], 'app', 'X1', show_max=True ); gc.collect()
train_df = do_countuniq( train_df, ['ip', 'hour'], 'minute', 'X2', 'uint8', show_max=True ); gc.collect()
train_df = do_countuniq( train_df, ['ip'], 'app', 'X3', 'uint8', show_max=True ); gc.collect()
train_df = do_countuniq( train_df, ['ip', 'app'], 'os', 'X4', 'uint8', show_max=True ); gc.collect()
train_df = do_countuniq( train_df, ['ip'], 'device', 'X5', 'uint16', show_max=True ); gc.collect()
train_df = do_countuniq( train_df, ['app'], 'channel', 'X6', show_max=True ); gc.collect()
train_df = do_cumcount( train_df, ['ip'], 'os', 'X7', show_max=True ); gc.collect()
train_df = do_countuniq( train_df, ['ip', 'device', 'os'], 'app', 'X8', show_max=True ); gc.collect()
train_df = do_count( train_df, ['ip', 'hour'], 'ip_tcount', show_max=True ); gc.collect()
train_df = do_count( train_df, ['ip', 'hour', 'minute'], 'ip_t_mcount', show_max=True ); gc.collect()
train_df = do_count( train_df, ['ip', 'app'], 'ip_app_count', show_max=True ); gc.collect()
train_df = do_count( train_df, ['ip', 'app', 'os'], 'ip_app_os_count', 'uint16', show_max=True ); gc.collect()
train_df = do_mean( train_df, ['ip', 'app', 'channel'], 'hour', 'ip_app_channel_mean_hour', show_max=True ); gc.collect()
train_df = do_mean( train_df, ['ip', 'app', 'channel', 'hour'], 'minute', 'ip_app_channel_h_mean_m', show_max=True ); gc.collect()
train_df = do_count( train_df, ['ip'], 'ip_count', 'uint16', show_max=True ); gc.collect()
train_df = do_click_shift( train_df, ['ip'], 'i_next_click'); gc.collect()
train_df = do_click_shift( train_df, ['ip', 'app'], 'ia_next_click'); gc.collect()
train_df = do_click_shift( train_df, ['ip', 'channel'], 'ic_next_click'); gc.collect()
train_df = do_click_shift( train_df, ['ip', 'os'], 'io_next_click'); gc.collect()
train_df = do_click_shift( train_df, ['ip', 'os', 'device'], 'iod_next_click')
# Out:
# Calculating skew of  hour  by  ['ip', 'app', 'os'] ...
# ip_app_os_skew_h max value =  7.338100515521791
# Calculating variance of  hour  by  ['ip', 'app', 'os'] ...
# ip_app_os_var_h max value =  264.5
# Calculating skew of  fives  by  ['ip', 'app', 'os', 'hour'] ...
# ip_app_os_skew_f max value =  6.794849630746133
# Calculating variance of  fives  by  ['ip', 'app', 'os', 'hour'] ...
# ip_app_os_var_f max value =  1512.5
# Calculating skew of  hour  by  ['ip', 'device', 'os'] ...
# ip_dev_os_skew_h max value =  8.124038404635966
# Calculating variance of  hour  by  ['ip', 'device', 'os'] ...
# ip_dev_os_var_h max value =  264.5
# Calculating skew of  fives  by  ['ip', 'device', 'os', 'hour'] ...
# ip_dev_os_skew_f max value =  6.335950539104124
# Calculating variance of  fives  by  ['ip', 'device', 'os', 'hour'] ...
# ip_dev_os_var_f max value =  1512.5
# Calculating skew of  minute  by  ['ip', 'app', 'os'] ...
# ip_app_os_skew_m max value =  5.092073653557608
# Calculating variance of  minute  by  ['ip', 'app', 'os'] ...
# ip_app_os_var_m max value =  1740.5
# Calculating skew of  minute  by  ['ip', 'app', 'os', 'hour'] ...
# ip_app_os_h_skew_m max value =  8.835513382120952
# Calculating variance of  minute  by  ['ip', 'app', 'os', 'hour'] ...
# ip_app_os_h_var_m max value =  1740.5
# Counting unqiue  channel  by  ['ip'] ...
# X0 max value =  147
# Cumulative count by  ['ip', 'device', 'os'] ...
# X1 max value =  23195
# Counting unqiue  minute  by  ['ip', 'hour'] ...
# X2 max value =  60
# Counting unqiue  app  by  ['ip'] ...
# X3 max value =  160
# Counting unqiue  os  by  ['ip', 'app'] ...
# X4 max value =  96
# Counting unqiue  device  by  ['ip'] ...
# X5 max value =  118
# Counting unqiue  channel  by  ['app'] ...
# X6 max value =  41
# Cumulative count by  ['ip'] ...
# X7 max value =  116216
# Counting unqiue  app  by  ['ip', 'device', 'os'] ...
# X8 max value =  56
# Aggregating by  ['ip', 'hour'] ...
# ip_tcount max value =  12731
# Aggregating by  ['ip', 'hour', 'minute'] ...
# ip_t_mcount max value =  273
# Aggregating by  ['ip', 'app'] ...
# ip_app_count max value =  17992
# Aggregating by  ['ip', 'app', 'os'] ...
# ip_app_os_count max value =  4442
# Calculating mean of  hour  by  ['ip', 'app', 'channel'] ...
# ip_app_channel_mean_hour max value =  23.0
# Calculating mean of  minute  by  ['ip', 'app', 'channel', 'hour'] ...
# ip_app_channel_h_mean_m max value =  59.0
# Aggregating by  ['ip'] ...
# ip_count max value =  116217
# Aggregating by  ['ip'] ...
# Aggregating by  ['ip', 'app'] ...
# Aggregating by  ['ip', 'channel'] ...
# Aggregating by  ['ip', 'os'] ...
# Aggregating by  ['ip', 'os', 'device'] ...

# %%
gc.collect()
# Out:
# 174

# %%
train_df.to_feather(f'{PATH}tmp/feature_df.feather')

# %% [markdown]
# y still needs to be dropped from train_df before modeling, by the way...

# %%
train_df.head()
# Out:
#        index      ip  app  device  os  channel          click_time  \
# 0   46430117  100929    2       2  20       18 2017-11-07 11:40:03
# 1  115447639   66638   15       2   8      245 2017-11-08 14:06:01
# 2   62753353  240419   12       1   1      265 2017-11-07 17:29:33
# 3   24690703  148460    2       1  13      469 2017-11-07 04:35:50
# 4   89013219  121359    2       1  19      477 2017-11-08 06:00:49
#
#    is_attributed  hour  minute       ...        ip_app_count  ip_app_os_count  \
# 0              0    11      40       ...                 235                2
# 1              0    14       6       ...                 104               19
# 2              0    17      29       ...                  11                3
# 3              0     4      35       ...                  15                5
# 4              0     6       0       ...                 117               28
#
#    ip_app_channel_mean_hour  ip_app_channel_h_mean_m  ip_count  i_next_click  \
# 0                 12.142858                25.000000      3493       52821.0
# 1                 12.666667                29.714285       884       60856.0
# 2                 14.500000                30.333334        67       26876.0
# 3                  7.000000                35.000000       208       80276.0
# 4                 11.450000                27.000000      1228       59569.0
#
#    ia_next_click  ic_next_click  io_next_click  iod_next_click
# 0        32441.0        10414.0        59601.0         84281.0
# 1         3223.0         3223.0        77674.0         84989.0
# 2        26876.0          131.0          126.0           126.0
# 3        21619.0        19055.0        74206.0         74206.0
# 4        47262.0        47262.0        59569.0         59569.0
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Feature Importance

# %%
df = pd.read_feather(f'{PATH}tmp/feature_df.feather', nthreads=4)
# Out:
# ---------------------------------------------------------------------------
# ArrowIOError                              Traceback (most recent call last)
# <ipython-input-21-cb8be5acb420> in <module>()
# ----> 1 df = pd.read_feather(f'{PATH}tmp/feature_df.feather', nthreads=4)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/io/feather_format.py in read_feather(path, nthreads)
#     110         return feather.read_dataframe(path)
#     111
# --> 112     return feather.read_dataframe(path, nthreads=nthreads)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pyarrow/feather.py in read_feather(source, columns, nthreads)
#     129     df : pandas.DataFrame
#     130     """
# --> 131     reader = FeatherReader(source)
#     132     return reader.read(columns=columns, nthreads=nthreads)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pyarrow/feather.py in __init__(self, source)
#      41     def __init__(self, source):
#      42         self.source = source
# ---> 43         self.open(source)
#      44
#      45     def read(self, columns=None, nthreads=1):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pyarrow/feather.pxi in pyarrow.lib.FeatherReader.open (/arrow/python/build/temp.linux-x86_64-3.6/lib.cxx:73987)()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pyarrow/io.pxi in pyarrow.lib.get_reader (/arrow/python/build/temp.linux-x86_64-3.6/lib.cxx:58504)()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pyarrow/io.pxi in pyarrow.lib.memory_map (/arrow/python/build/temp.linux-x86_64-3.6/lib.cxx:54834)()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pyarrow/io.pxi in pyarrow.lib.MemoryMappedFile._open (/arrow/python/build/temp.linux-x86_64-3.6/lib.cxx:54613)()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pyarrow/error.pxi in pyarrow.lib.check_status (/arrow/python/build/temp.linux-x86_64-3.6/lib.cxx:8345)()
#
# ArrowIOError: Failed to open local file: data/fraud-detection/tmp/feature_df.feather , error: No such file or directory

# %%
del test_df
gc.collect()
# Out:
# 3252

# %%
n_trn = 10000000

# %%
train_df.dtypes
# Out:
# index                                int64
# ip                                  uint32
# app                                 uint16
# device                              uint16
# os                                  uint16
# channel                             uint16
# click_time                  datetime64[ns]
# is_attributed                        uint8
# hour                                 uint8
# minute                               uint8
# fives                                uint8
# ip_app_os_skew_h                   float32
# ip_app_os_var_h                    float32
# ip_app_os_skew_f                   float32
# ip_app_os_var_f                    float32
# ip_dev_os_skew_h                   float32
# ip_dev_os_var_h                    float32
# ip_dev_os_skew_f                   float32
# ip_dev_os_var_f                    float32
# ip_app_os_skew_m                   float32
# ip_app_os_var_m                    float32
# ip_app_os_h_skew_m                 float32
# ip_app_os_h_var_m                  float32
# X0                                   uint8
# X1                                  uint32
# X2                                   uint8
# X3                                   uint8
# X4                                   uint8
# X5                                  uint16
# X6                                  uint32
# X7                                  uint32
# X8                                  uint32
# ip_tcount                           uint32
# ip_t_mcount                         uint32
# ip_app_count                        uint32
# ip_app_os_count                     uint16
# ip_app_channel_mean_hour           float32
# ip_app_channel_h_mean_m            float32
# ip_count                            uint16
# i_next_click                       float32
# ia_next_click                      float32
# ic_next_click                      float32
# io_next_click                      float32
# iod_next_click                     float32
# dtype: object

# %%
is_number = np.vectorize(lambda x: np.issubdtype(x, np.number))
is_number(df.dtypes)
# Out:
# array([ True,  True,  True,  True,  True, False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ### Dealing with NaNs

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %% [markdown]
# <b>our data got out of order...probably during sampling</b>

# %%
train_df.head(3)
# Out:
#        index      ip  app  device  os  channel          click_time  \
# 0   46430117  100929    2       2  20       18 2017-11-07 11:40:03
# 1  115447639   66638   15       2   8      245 2017-11-08 14:06:01
# 2   62753353  240419   12       1   1      265 2017-11-07 17:29:33
#
#    is_attributed  hour  minute       ...        ip_app_count  ip_app_os_count  \
# 0              0    11      40       ...                 235                2
# 1              0    14       6       ...                 104               19
# 2              0    17      29       ...                  11                3
#
#    ip_app_channel_mean_hour  ip_app_channel_h_mean_m  ip_count  i_next_click  \
# 0                 12.142858                25.000000      3493       52821.0
# 1                 12.666667                29.714285       884       60856.0
# 2                 14.500000                30.333334        67       26876.0
#
#    ia_next_click  ic_next_click  io_next_click  iod_next_click
# 0        32441.0        10414.0        59601.0         84281.0
# 1         3223.0         3223.0        77674.0         84989.0
# 2        26876.0          131.0          126.0           126.0
#
# [3 rows x 44 columns]

# %%
# could also sort by click_time but here they are equivalent and betting index is faster
train_df = train_df.sort_values(by=['index'])

# %%
display_all(train_df.tail(3).transpose())
# Out:
#                                      11559824             10811585  \
# index                               184903427            184903435
# ip                                      48240                  209
# app                                         3                   18
# device                                      1                    1
# os                                         32                   19
# channel                                    30                  107
# click_time                2017-11-09 15:59:59  2017-11-09 15:59:59
# is_attributed                               0                    0
# hour                                       15                   15
# minute                                     59                   59
# fives                                       0                    0
# ip_app_os_skew_h                    -0.863862              1.35853
# ip_app_os_var_h                       17.0087              5.16667
# ip_app_os_skew_f                     0.445584                  NaN
# ip_app_os_var_f                       741.667                  NaN
# ip_dev_os_skew_h                    0.0161904            -0.299614
# ip_dev_os_var_h                       22.2762              19.9081
# ip_dev_os_skew_f                    0.0789212            -0.715362
# ip_dev_os_var_f                       332.684              367.411
# ip_app_os_skew_m                    0.0168959             0.524088
# ip_app_os_var_m                       312.137              370.423
# ip_app_os_h_skew_m                    -1.4941                  NaN
# ip_app_os_h_var_m                     150.333                  NaN
# X0                                        133                   79
# X1                                        157                   99
# X2                                         60                   19
# X3                                         67                   32
# X4                                         63                   19
# X5                                         11                    5
# X6                                         39                   15
# X7                                      11330                  424
# X8                                         26                   21
# ip_tcount                                1547                   28
# ip_t_mcount                                18                    2
# ip_app_count                             3577                   55
# ip_app_os_count                            52                   13
# ip_app_channel_mean_hour              11.6652              12.4231
# ip_app_channel_h_mean_m               27.6729                   59
# ip_count                                18872                  655
# i_next_click                            66407                54580
# ia_next_click                           81799                50552
# ic_next_click                           58325                50552
# io_next_click                           81915                52010
# iod_next_click                          81915                52010
#
#                                      12641883
# index                               184903436
# ip                                      92190
# app                                        12
# device                                      1
# os                                         23
# channel                                   340
# click_time                2017-11-09 15:59:59
# is_attributed                               0
# hour                                       15
# minute                                     59
# fives                                       0
# ip_app_os_skew_h                    -0.585583
# ip_app_os_var_h                       25.3333
# ip_app_os_skew_f                          NaN
# ip_app_os_var_f                           NaN
# ip_dev_os_skew_h                    -0.327351
# ip_dev_os_var_h                       20.2667
# ip_dev_os_skew_f                          NaN
# ip_dev_os_var_f                             0
# ip_app_os_skew_m                     -1.05583
# ip_app_os_var_m                           399
# ip_app_os_h_skew_m                        NaN
# ip_app_os_h_var_m                         NaN
# X0                                         27
# X1                                          2
# X2                                          2
# X3                                         13
# X4                                          3
# X5                                          1
# X6                                         30
# X7                                         18
# X8                                          3
# ip_tcount                                   4
# ip_t_mcount                                 2
# ip_app_count                                6
# ip_app_os_count                             3
# ip_app_channel_mean_hour                   13
# ip_app_channel_h_mean_m                    59
# ip_count                                   35
# i_next_click                            53863
# ia_next_click                           49645
# ic_next_click                             NaN
# io_next_click                           49671
# iod_next_click                          49671

# %%
display_all(train_df.isnull().sum().sort_index()/len(train_df))
# Out:
# X0                          0.000000
# X1                          0.000000
# X2                          0.000000
# X3                          0.000000
# X4                          0.000000
# X5                          0.000000
# X6                          0.000000
# X7                          0.000000
# X8                          0.000000
# app                         0.000000
# channel                     0.000000
# click_time                  0.000000
# device                      0.000000
# fives                       0.000000
# hour                        0.000000
# i_next_click                0.009178
# ia_next_click               0.093217
# ic_next_click               0.196380
# index                       0.000000
# io_next_click               0.093894
# iod_next_click              0.100657
# ip                          0.000000
# ip_app_channel_h_mean_m     0.000000
# ip_app_channel_mean_hour    0.000000
# ip_app_count                0.000000
# ip_app_os_count             0.000000
# ip_app_os_h_skew_m          0.753509
# ip_app_os_h_var_m           0.584969
# ip_app_os_skew_f            0.753509
# ip_app_os_skew_h            0.356943
# ip_app_os_skew_m            0.356943
# ip_app_os_var_f             0.584969
# ip_app_os_var_h             0.234440
# ip_app_os_var_m             0.234440
# ip_count                    0.000000
# ip_dev_os_skew_f            0.314015
# ip_dev_os_skew_h            0.065683
# ip_dev_os_var_f             0.180691
# ip_dev_os_var_h             0.034707
# ip_t_mcount                 0.000000
# ip_tcount                   0.000000
# is_attributed               0.000000
# minute                      0.000000
# os                          0.000000
# dtype: float64

# %%
train_df.columns
# Out:
# Index(['index', 'ip', 'app', 'device', 'os', 'channel', 'click_time',
#        'is_attributed', 'hour', 'minute', 'fives', 'ip_app_os_skew_h',
#        'ip_app_os_var_h', 'ip_app_os_skew_f', 'ip_app_os_var_f',
#        'ip_dev_os_skew_h', 'ip_dev_os_var_h', 'ip_dev_os_skew_f',
#        'ip_dev_os_var_f', 'ip_app_os_skew_m', 'ip_app_os_var_m',
#        'ip_app_os_h_skew_m', 'ip_app_os_h_var_m', 'X0', 'X1', 'X2', 'X3', 'X4',
#        'X5', 'X6', 'X7', 'X8', 'ip_tcount', 'ip_t_mcount', 'ip_app_count',
#        'ip_app_os_count', 'ip_app_channel_mean_hour',
#        'ip_app_channel_h_mean_m', 'ip_count', 'i_next_click', 'ia_next_click',
#        'ic_next_click', 'io_next_click', 'iod_next_click'],
#       dtype='object')

# %% [markdown]
# If we want to not use medians like proc df we can use the below list...

# %%
# preparing lists of columns to perform fillna on
cat_fill = ['ip', 'app', 'device', 'os', 'channel']

num_fill = ['ip_app_os_skew_h',
       'ip_app_os_var_h', 'ip_app_os_skew_f', 'ip_app_os_var_f',
       'ip_dev_os_skew_h', 'ip_dev_os_var_h', 'ip_dev_os_skew_f',
       'ip_dev_os_var_f', 'ip_app_os_skew_m', 'ip_app_os_var_m',
       'ip_app_os_h_skew_m', 'ip_app_os_h_var_m','ip_app_count',
       'ip_app_os_count', 'i_next_click', 'ia_next_click',
       'ic_next_click', 'io_next_click', 'iod_next_click']

other_fill = ['ip_app_channel_mean_hour', 'ip_app_channel_h_mean_m' ]

# %%
for column in num_fill:
    train_df[column].fillna()

# %%
??train_cats(train_df)

# %% [markdown]
# <b>proc_df did not properly fill nas</b>

# %%
hm_df.head()
# Out:
#              ip  app  device  os  channel  is_attributed  hour  minute  fives  \
# 1344910   20173   18       1  13      134              0     0       0      5
# 695655    75722   12       1  13      178              0     0       0      5
# 4127104  195610    9       1  16      134              0     0       0      5
# 5400380  126230   14       1  53      134              0     0       0      5
# 9758181  148473   20       1  25      259              0     0       0      5
#
#          ip_app_os_skew_h       ...        ip_app_count  ip_app_os_count  \
# 1344910         -0.492789       ...                  47               13
# 695655          -1.017810       ...                  12                7
# 4127104               NaN       ...                   3                2
# 5400380               NaN       ...                  15                1
# 9758181               NaN       ...                   5                1
#
#          ip_app_channel_mean_hour  ip_app_channel_h_mean_m  ip_count  \
# 1344910                       8.5                      0.0       468
# 695655                        4.8                      0.0       106
# 4127104                       0.0                      0.0        34
# 5400380                       5.0                      0.0       215
# 9758181                       4.2                      0.0        89
#
#          i_next_click  ia_next_click  ic_next_click  io_next_click  \
# 1344910       32871.0        32871.0          764.0        28761.0
# 695655        10621.0        32811.0        26371.0        52827.0
# 4127104       40490.0        39765.0        46731.0            NaN
# 5400380       63717.0        36386.0        36386.0          342.0
# 9758181           NaN            NaN            NaN            NaN
#
#          iod_next_click
# 1344910         28761.0
# 695655          52827.0
# 4127104             NaN
# 5400380           342.0
# 9758181             NaN
#
# [5 rows x 42 columns]

# %%
for column in hm_df.columns:
    if column in num_fill:
        print(column)
        for n,c in hm_df.items():
            c.fillna(c.median(), inplace=True)
# Out:
# ip_app_os_skew_h
# ip_app_os_var_h
# ip_app_os_skew_f
# ip_app_os_var_f
# ip_dev_os_skew_h
# ip_dev_os_var_h
# ip_dev_os_skew_f
# ip_dev_os_var_f
# ip_app_os_skew_m
# ip_app_os_var_m
# ip_app_os_h_skew_m
# ip_app_os_h_var_m
# ip_app_count
# ip_app_os_count
# i_next_click
# ia_next_click
# ic_next_click
# io_next_click
# iod_next_click

# %%
display_all(hm_df.head(3).transpose())
# Out:
#                                1344910       695655         4127104
# ip                        20173.000000  75722.000000  195610.000000
# app                          18.000000     12.000000       9.000000
# device                        1.000000      1.000000       1.000000
# os                           13.000000     13.000000      16.000000
# channel                     134.000000    178.000000     134.000000
# is_attributed                 0.000000      0.000000       0.000000
# hour                          0.000000      0.000000       0.000000
# minute                        0.000000      0.000000       0.000000
# fives                         5.000000      5.000000       5.000000
# ip_app_os_skew_h             -0.492789     -1.017810       0.144139
# ip_app_os_var_h              27.000000     15.238095       0.000000
# ip_app_os_skew_f              0.830707      0.830707       0.830707
# ip_app_os_var_f             177.500000    177.500000       0.000000
# ip_dev_os_skew_h              0.111338      0.451883       0.000000
# ip_dev_os_var_h              23.814913     22.663664       0.000000
# ip_dev_os_skew_f             -1.360828      0.112137       0.000000
# ip_dev_os_var_f              37.500000    185.030487       0.000000
# ip_app_os_skew_m             -0.447813      0.653872       0.269979
# ip_app_os_var_m             387.935883    397.952393       0.000000
# ip_app_os_h_skew_m            0.554506      0.554506       0.554506
# ip_app_os_h_var_m           447.483337    447.483337       0.000000
# X0                           83.000000     53.000000      21.000000
# X1                           13.000000      1.000000       2.000000
# X2                           13.000000      2.000000       3.000000
# X3                           35.000000     22.000000      13.000000
# X4                           20.000000      6.000000       2.000000
# X5                            3.000000      4.000000       2.000000
# X6                           15.000000     30.000000      41.000000
# X7                           52.000000      3.000000      17.000000
# X8                           19.000000     13.000000       2.000000
# ip_tcount                    16.000000      2.000000       6.000000
# ip_t_mcount                   1.000000      1.000000       3.000000
# ip_app_count                 47.000000     12.000000       3.000000
# ip_app_os_count              13.000000      7.000000       2.000000
# ip_app_channel_mean_hour      8.500000      4.800000       0.000000
# ip_app_channel_h_mean_m       0.000000      0.000000       0.000000
# ip_count                    468.000000    106.000000      34.000000
# i_next_click              32871.000000  10621.000000   40490.000000
# ia_next_click             32871.000000  32811.000000   39765.000000
# ic_next_click               764.000000  26371.000000   46731.000000
# io_next_click             28761.000000  52827.000000   28761.000000
# iod_next_click            28761.000000  52827.000000   28761.000000

# %%
gc.collect()
# Out:
# 802

# %% [markdown]
# Let's see if we caught all the nulls

# %%
display_all(hm_df.isnull().sum().sort_index()/len(hm_df))
# Out:
# X0                          0.0
# X1                          0.0
# X2                          0.0
# X3                          0.0
# X4                          0.0
# X5                          0.0
# X6                          0.0
# X7                          0.0
# X8                          0.0
# app                         0.0
# channel                     0.0
# device                      0.0
# fives                       0.0
# hour                        0.0
# i_next_click                0.0
# ia_next_click               0.0
# ic_next_click               0.0
# io_next_click               0.0
# iod_next_click              0.0
# ip                          0.0
# ip_app_channel_h_mean_m     0.0
# ip_app_channel_mean_hour    0.0
# ip_app_count                0.0
# ip_app_os_count             0.0
# ip_app_os_h_skew_m          0.0
# ip_app_os_h_var_m           0.0
# ip_app_os_skew_f            0.0
# ip_app_os_skew_h            0.0
# ip_app_os_skew_m            0.0
# ip_app_os_var_f             0.0
# ip_app_os_var_h             0.0
# ip_app_os_var_m             0.0
# ip_count                    0.0
# ip_dev_os_skew_f            0.0
# ip_dev_os_skew_h            0.0
# ip_dev_os_var_f             0.0
# ip_dev_os_var_h             0.0
# ip_t_mcount                 0.0
# ip_tcount                   0.0
# is_attributed               0.0
# minute                      0.0
# os                          0.0
# dtype: float64

# %% [markdown]
# ### Base Model

# %%
def print_score(m):
    res = [metrics.roc_auc_score(y_train, m.predict(X_train)), metrics.roc_auc_score(y_valid, m.predict(X_valid)),
          m.score(X_train, y_train), m.score(X_valid, y_valid)]
    if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
columns = [
    #'ip', 
           'app', 'device', 'os', 'channel','hour', 'minute', 'fives', 'ip_app_os_skew_h',
       'ip_app_os_var_h', 'ip_app_os_skew_f', 'ip_app_os_var_f',
#       'ip_dev_os_skew_h', 'ip_dev_os_var_h', 'ip_dev_os_skew_f',
 #      'ip_dev_os_var_f', 'ip_app_os_skew_m', 'ip_app_os_var_m',
       'ip_app_os_h_skew_m', 'ip_app_os_h_var_m', 'X0', 'X1', 'X2', 'X3', 'X4',
       'X5', 'X6', 'X7', 'X8', 'ip_tcount', 'ip_t_mcount', 'ip_app_count',
       'ip_app_os_count', 'ip_app_channel_mean_hour',
       'ip_app_channel_h_mean_m', 
    #'ip_count', 
    'i_next_click', 'ia_next_click',
       'ic_next_click', 'io_next_click', 'iod_next_click']

# %%
target = ['is_attributed']

# %%
n_trn = 10000000

# %%
y_hm = x_hm['is_attributed'].values

# %%
x_hm.shape, y_hm.shape
# Out:
# ((15000000, 58), (15000000,))

# %%
??proc_df

# %% [markdown]
# without ips

# %%
def split_vals(a,n): return a[:n].copy(), a[n:].copy()

X_train, X_valid = split_vals(x_hm[columns], n_trn)
y_train, y_valid = split_vals(y_hm, n_trn)

X_train.shape, y_train.shape, X_valid.shape
# Out:
# ((10000000, 33), (10000000,), (5000000, 33))

# %%
set_rf_samples(1000000)

# %%
m=RandomForestClassifier(n_estimators=20, max_features=0.5, min_samples_leaf=5, n_jobs=-1)
# %time m.fit(X_train, y_train)
print_score(m)
# Out:
# CPU times: user 21min 54s, sys: 9.22 s, total: 22min 3s
# Wall time: 3min 16s
# [0.7178181534753137, 0.562553900335945, 0.9983435, 0.9989822]

# %% [markdown]
# without ip counts

# %%
def split_vals(a,n): return a[:n].copy(), a[n:].copy()

X_train, X_valid = split_vals(x_hm[columns], n_trn)
y_train, y_valid = split_vals(y_hm, n_trn)

X_train.shape, y_train.shape, X_valid.shape
# Out:
# ((10000000, 40), (10000000,), (5000000, 40))

# %%
gc.collect()
# Out:
# 4080

# %%
m=RandomForestClassifier(n_estimators=20, max_features=0.5, min_samples_leaf=5, n_jobs=-1)
# %time m.fit(X_train, y_train)
print_score(m)
# Out:
# CPU times: user 20min 52s, sys: 7.53 s, total: 20min 59s
# Wall time: 3min 7s
# [0.7177396504834318, 0.5621909699425857, 0.9983454, 0.998979]

# %% [markdown]
# without ip or ip count

# %%
gc.collect()
# Out:
# 4080

# %%
m=RandomForestClassifier(n_estimators=20, max_features=0.5, min_samples_leaf=5, n_jobs=-1)
# %time m.fit(X_train, y_train)
print_score(m)
# Out:
# CPU times: user 19min 29s, sys: 7.95 s, total: 19min 37s
# Wall time: 3min 1s
# [0.7237564408483589, 0.5620111065171446, 0.9983415, 0.9989806]

# %% [markdown]
# without a bunch of features: 'ip_dev_os_skew_h', 'ip_dev_os_var_h', 'ip_dev_os_skew_f',
#       'ip_dev_os_var_f', 'ip_app_os_skew_m', 'ip_app_os_var_m',

# %%
m=RandomForestClassifier(n_estimators=20, max_features=0.5, min_samples_leaf=5, n_jobs=-1)
# %time m.fit(X_train, y_train)
print_score(m)
# Out:
# CPU times: user 15min 46s, sys: 7.53 s, total: 15min 54s
# Wall time: 2min 25s
# [0.7192675124557447, 0.5625537001145402, 0.9983422, 0.9989818]

# %%
# %time X_train['ip_app_os_skew_h'].iloc[:30].rolling(5).mean() #-0.229399 4.35s
# Out:
# CPU times: user 505 µs, sys: 0 ns, total: 505 µs
# Wall time: 379 µs
# 1344910         NaN
# 695655          NaN
# 4127104         NaN
# 5400380         NaN
# 9758181   -0.229399
# 5887743   -0.106601
# 2150876    0.147837
# 8660526    0.265057
# 4467339    0.265057
# 5008883    0.344250
# 6173687    0.557885
# 8760391    0.577269
# 3081752    0.460048
# 5404209    0.555948
# 3729169    0.476755
# 3884624    0.410344
# 5616801    0.364324
# 6074861    0.469970
# 2698128    0.333364
# 8574959    0.820471
# 2721879    0.588617
# 8009822    0.288478
# 2659099    0.074654
# 1378087    0.292436
# 4548284   -0.194671
# 3301348   -0.146643
# 332957     0.136036
# 6962398    0.244214
# 412005    -0.241503
# 8742481   -0.305800
# Name: ip_app_os_skew_h, dtype: float64

# %%
def moving_average(data, window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(data, window, 'same')

# %time moving_average(X_train['ip_app_os_skew_h'].iloc[:30], 5)
# Out:
# CPU times: user 214 µs, sys: 4 µs, total: 218 µs
# Wall time: 221 µs
# array([-0.27788, -0.25364, -0.2294 , -0.1066 ,  0.14784,  0.26506,  0.26506,  0.34425,  0.55788,  0.57727,
#         0.46005,  0.55595,  0.47675,  0.41034,  0.36432,  0.46997,  0.33336,  0.82047,  0.58862,  0.28848,
#         0.07465,  0.29244, -0.19467, -0.14664,  0.13604,  0.24421, -0.2415 , -0.3058 , -0.29344, -0.30022])

# %%
def get_deviation(y, window_size):
    avg = moving_average(y, window_size).tolist()
    residual = y - avg
    testing_std = pd.rolling_std(residual, window_size)
    testing_std_as_df = pd.DataFrame(testing_std)
    rolling_std = testing_std_as_df.replace(np.nan,
                                  testing_std_as_df.iloc[window_size - 1]).round(3).iloc[:,0].tolist()
    return rolling_std[:50]

# %time get_deviation(X_train['ip_app_os_skew_h'].iloc[:500000], 5)
# Out:
# CPU times: user 44.4 ms, sys: 12 ms, total: 56.4 ms
# Wall time: 112 ms
# /home/zlandes/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5,center=False).std()
#   after removing the cwd from sys.path.
# [0.439,
#  0.439,
#  0.439,
#  0.439,
#  0.439,
#  0.434,
#  0.203,
#  0.207,
#  0.288,
#  0.287,
#  0.444,
#  0.466,
#  0.467,
#  0.425,
#  0.445,
#  0.318,
#  0.319,
#  0.282,
#  0.377,
#  1.152,
#  1.191,
#  1.456,
#  1.457,
#  1.517,
#  1.008,
#  1.005,
#  0.59,
#  0.55,
#  0.64,
#  0.643,
#  0.699,
#  0.689,
#  0.627,
#  0.442,
#  0.458,
#  0.578,
#  0.575,
#  0.876,
#  0.828,
#  0.826,
#  1.164,
#  1.249,
#  1.032,
#  1.048,
#  1.03,
#  0.683,
#  0.75,
#  0.824,
#  0.753,
#  0.842]

# %%
def get_rolling_std(y, window_size):
    avg = moving_average(y, window_size)
    residual = y - avg
    testing_std = pd.rolling_std(residual, window_size)
    testing_std_as_df = pd.DataFrame(testing_std)
    rolling_std = testing_std_as_df.replace(np.nan,
                                  testing_std_as_df.iloc[window_size - 1]).round(3).iloc[:,0].tolist()
    return rolling_std[:50]

# %time get_rolling_std(X_train['ip_app_os_skew_h'], 5)
# Out:
# /home/zlandes/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5,center=False).std()
#   after removing the cwd from sys.path.
# CPU times: user 545 ms, sys: 340 ms, total: 885 ms
# Wall time: 826 ms
# [0.439,
#  0.439,
#  0.439,
#  0.439,
#  0.439,
#  0.434,
#  0.203,
#  0.207,
#  0.288,
#  0.287,
#  0.444,
#  0.466,
#  0.467,
#  0.425,
#  0.445,
#  0.318,
#  0.319,
#  0.282,
#  0.377,
#  1.152,
#  1.191,
#  1.456,
#  1.457,
#  1.517,
#  1.008,
#  1.005,
#  0.59,
#  0.55,
#  0.64,
#  0.643,
#  0.699,
#  0.689,
#  0.627,
#  0.442,
#  0.458,
#  0.578,
#  0.575,
#  0.876,
#  0.828,
#  0.826,
#  1.164,
#  1.249,
#  1.032,
#  1.048,
#  1.03,
#  0.683,
#  0.75,
#  0.824,
#  0.753,
#  0.842]

# %%
def moving_average(data, window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(data, window, 'same')

def get_rolling_std(df, group_cols, col, window_size, show_max=False, show_agg=True):
    if show_agg:
        print( "Calculating std deviation of MA of ", col, '...' )
    gp = df[group_cols + [col]].groupby(group_cols)
    avg = gp[col].transform(lambda x: moving_average(x, window_size)).reset_index()
    residual = gp[col] - moving_average(df[group_cols + [col]].groupby(group_cols)[col], window_size)
#     for name, group in gp[col]
#     testing_std = pd.rolling_std(residual, window_size)
#     testing_std_as_df = pd.DataFrame(testing_std)
#     #df[col + '_std'] = 
#     rolling_std = testing_std_as_df.replace(np.nan,
#                                   testing_std_as_df.iloc[window_size - 1]).round(3).iloc[:,0].tolist()
    gc.collect()
    return residual#rolling_std#df

get_rolling_std(X_train.iloc[:50], ['app', 'channel'], 'X6', 5, show_max=True)
# Out:
# Calculating std deviation of MA of  X6 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-252-f1f3046bfa8c> in <module>()
#      18     return residual#rolling_std#df
#      19
# ---> 20 get_rolling_std(X_train.iloc[:50], ['app', 'channel'], 'X6', 5, show_max=True)
#
# <ipython-input-252-f1f3046bfa8c> in get_rolling_std(df, group_cols, col, window_size, show_max, show_agg)
#       7         print( "Calculating std deviation of MA of ", col, '...' )
#       8     gp = df[group_cols + [col]].groupby(group_cols)
# ----> 9     avg = gp[col].transform(lambda x: moving_average(x, window_size)).reset_index()
#      10     residual = gp[col] - moving_average(df[group_cols + [col]].groupby(group_cols)[col], window_size)
#      11 #     for name, group in gp[col]
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/groupby.py in transform(self, func, *args, **kwargs)
#    3299
#    3300             indexer = self._get_index(name)
# -> 3301             s = klass(res, indexer)
#    3302             results.append(s)
#    3303
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     264                                        raise_cast_failure=True)
#     265
# --> 266                 data = SingleBlockManager(data, index, fastpath=True)
#     267
#     268         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4400         if not isinstance(block, Block):
#    4401             block = make_block(block, placement=slice(0, len(axis)), ndim=1,
# -> 4402                                fastpath=True)
#    4403
#    4404         self.blocks = [block]
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2955                      placement=placement, dtype=dtype)
#    2956
# -> 2957     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2958
#    2959 # TODO: flexible with index=None and/or items=None
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim, fastpath)
#     118             raise ValueError('Wrong number of items passed %d, placement '
#     119                              'implies %d' % (len(self.values),
# --> 120                                              len(self.mgr_locs)))
#     121
#     122     @property
#
# ValueError: Wrong number of items passed 5, placement implies 1

# %%
gc.collect()
# Out:
# 290

# %%
get_rolling_std(X_train, 'ip_app_os_skew_h', 5, show_max=True)
# Out:
# Calculating std deviation of MA of  ip_app_os_skew_h ...
# /home/zlandes/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5,center=False).std()
#   # Remove the CWD from sys.path while we load stuff.
#          app  device  os  channel  hour  minute  fives  ip_app_os_skew_h  \
# 1344910   18       1  13      134     0       0      5         -0.492789
# 695655    12       1  13      178     0       0      5         -1.017810
# 4127104    9       1  16      134     0       0      5          0.121201
# 5400380   14       1  53      134     0       0      5          0.121201
# 9758181   20       1  25      259     0       0      5          0.121201
# 5887743   20       1  17      478     0       0      5          0.121201
# 2150876   12       1  25      328     0       0      5          0.254380
# 8660526   15       1  13      245     0       0      5          0.707305
# 4467339    3       1   9      130     0       0      5          0.121201
# 5008883    2       1  19      469     0       0      5          0.517166
# 6173687  151       0  24      347     0       0      5          1.189373
# 8760391   15       1  11      245     0       0      5          0.351301
# 3081752   14       1  13      446     0       0      5          0.121201
# 5404209   12       1  10      178     0       0      5          0.600698
# 3729169   12       1  17      481     0       0      5          0.121201
# 3884624   20       1  19      259     0       0      5          0.857321
# 5616801    8       1   8      145     0       0      5          0.121201
# 6074861   15       1  13      140     0       0      5          0.649430
# 2698128   12       1  13      245     0       0      5         -0.082333
# 8574959    8       1  13      145     0       0      5          2.556736
# 2721879    9       2  13      234     0       0      5         -0.301948
# 8009822   12       1  13      178     0       0      5         -1.379497
# 2659099   14       1  19      442     0       0      5         -0.419687
# 1378087    3       1  19      205     0       0      5          1.006575
# 4548284   26       1  13      266     0       0      5          0.121201
# 3301348    9       1  17      134     0       0      5         -0.061806
# 332957    18       1  19      121     0       0      5          0.033899
# 6962398   21       1  53      128     0       0      5          0.121201
# 412005     2       1  37      258     0       0      5         -1.422010
# 8742481   18       1  19      107     0       0      5         -0.200284
# ...      ...     ...  ..      ...   ...     ...    ...               ...
# 3680672   28       1  19      135    23      59      0          1.388861
# 2231593    9       1  13      466    23      59      0          0.216497
# 9846680   15       1  19      245    23      59      0          0.121201
# 6950729    2       1  18      219    23      59      0         -1.033266
# 6475885   12       1  17      245    23      59      0          0.614063
# 5205272   26       1  13      121    23      59      0          0.121201
# 4226622   19      18   0      213    23      59      0          0.121201
# 7827763   15       1  17      386    23      59      0          0.121201
# 4503575   21       1  19      128    23      59      0          0.121201
# 5322252   14       1  22      480    23      59      0          0.121201
# 7244452   18       1  13      134    23      59      0          0.507899
# 9223825   17       1  19      280    23      59      0          0.121201
# 4222520   15       1  19      379    23      59      0          0.012067
# 3542073   17       2  13      280    23      59      0          0.227185
# 7755686    9       1   8      134    23      59      0          1.643911
# 1118365    9       1  20      134    23      59      0          0.121201
# 313403    14       1  15      379    23      59      0          0.121201
# 263566    14       1  14      349    23      59      0          0.121201
# 9038291    3       1  15      211    23      59      0          0.518484
# 2512641    3       1  22      137    23      59      0          1.070915
# 9008706   15       1  41      386    23      59      0          1.270620
# 6531025   23       1  27      153    23      59      0          0.121201
# 7893752   18       1  31      107    23      59      0          0.121201
# 3262011   12       1  20      409    23      59      0          0.121201
# 3846366    1       1  53      115    23      59      0          0.121201
# 450230     9       1  20      334    23      59      0          0.121201
# 8919934   12       1  25      481    23      59      0          0.121201
# 1978490   12       1   3      245    23      59      0          0.121201
# 2620890   18       1  13      107    23      59      0          0.544127
# 5116481    1       1   8      150    23      59      0          0.121201
#
#          ip_app_os_var_h  ip_app_os_skew_f          ...           \
# 1344910        27.000000          0.000000          ...
# 695655         15.238095          0.000000          ...
# 4127104         0.000000          0.000000          ...
# 5400380        22.602299          0.000000          ...
# 9758181        22.602299          0.000000          ...
# 5887743        22.602299          0.000000          ...
# 2150876        60.700001          0.000000          ...
# 8660526        38.590645          2.000000          ...
# 4467339        22.602299          0.000000          ...
# 5008883        77.619049          0.000000          ...
# 6173687         0.218182          0.000000          ...
# 8760391        24.531242          0.000000          ...
# 3081752        22.602299          0.000000          ...
# 5404209        34.238094          0.000000          ...
# 3729169        22.602299          0.000000          ...
# 3884624        10.666667          1.732051          ...
# 5616801        50.000000          0.000000          ...
# 6074861        33.207829         -1.748792          ...
# 2698128        23.104040          0.000000          ...
# 8574959        18.953217          0.967052          ...
# 2721879        25.977123          0.694363          ...
# 8009822        12.266666          0.000000          ...
# 2659099        18.966667          0.000000          ...
# 1378087        37.282162          1.492685          ...
# 4548284        22.602299          0.000000          ...
# 3301348        20.861111          0.000000          ...
# 332957         23.056362         -0.353962          ...
# 6962398         0.000000          0.000000          ...
# 412005         31.700001          0.000000          ...
# 8742481        26.510262          0.000000          ...
# ...                  ...               ...          ...
# 3680672        96.666664          0.000000          ...
# 2231593        39.487179          0.000000          ...
# 9846680       112.500000          0.000000          ...
# 6950729        35.386154         -1.732051          ...
# 6475885        56.395832          0.000000          ...
# 5205272        12.500000          0.000000          ...
# 4226622        98.000000          0.000000          ...
# 7827763        22.602299          0.000000          ...
# 4503575        22.602299          0.000000          ...
# 5322252        22.602299          0.000000          ...
# 7244452        36.779411          0.000000          ...
# 9223825        22.602299          0.000000          ...
# 4222520        22.565567          0.000000          ...
# 3542073        47.171429          0.000000          ...
# 7755686        70.916664          0.000000          ...
# 1118365        22.602299          0.000000          ...
# 313403         22.602299          0.000000          ...
# 263566         22.602299          0.000000          ...
# 9038291        57.200001          0.000000          ...
# 2512641       139.000000          0.000000          ...
# 9008706        40.966667          0.000000          ...
# 6531025        22.602299          0.000000          ...
# 7893752        22.602299          0.000000          ...
# 3262011         0.000000          0.000000          ...
# 3846366       264.500000          0.000000          ...
# 450230         22.602299          0.000000          ...
# 8919934        22.602299          0.000000          ...
# 1978490        22.602299          0.000000          ...
# 2620890        47.416668          0.000000          ...
# 5116481        60.500000          0.000000          ...
#
#          ip_app_count  ip_app_os_count  ip_app_channel_mean_hour  \
# 1344910            47               13                  8.500000
# 695655             12                7                  4.800000
# 4127104             3                2                  0.000000
# 5400380            15                1                  5.000000
# 9758181             5                1                  4.200000
# 5887743             1                1                  0.000000
# 2150876           115                5                  8.043478
# 8660526            61               19                  7.608696
# 4467339            29                1                  0.000000
# 5008883            35                7                  8.333333
# 6173687            11               11                  0.272727
# 8760391          8944               95                 11.352423
# 3081752             3                1                  0.000000
# 5404209           141                7                  8.789474
# 3729169            34                1                  5.333333
# 3884624            14                6                  7.600000
# 5616801             3                2                  5.333333
# 6074861           119               39                  2.333333
# 2698128           154               45                 10.375000
# 8574959            50               19                  5.914894
# 2721879          1270              268                 11.179803
# 8009822            11                6                  4.800000
# 2659099            15                6                  8.666667
# 1378087           275               75                  6.250000
# 4548284            16                1                  6.428571
# 3301348            33                9                  0.000000
# 332957           1265              226                 10.517509
# 6962398            22                2                  7.941176
# 412005            160                5                  7.333333
# 8742481           342               71                 10.604167
# ...               ...              ...                       ...
# 3680672             8                4                  8.250000
# 2231593           112               27                 10.125000
# 9846680             6                2                 16.000000
# 6950729           259               26                 11.000000
# 6475885           305               16                 11.671641
# 5205272             2                2                 20.500000
# 4226622             2                2                 23.000000
# 7827763            44                1                 10.142858
# 4503575             2                1                 14.500000
# 5322252             2                1                 23.000000
# 7244452           125               17                  9.619047
# 9223825             2                1                 19.000000
# 4222520           330               91                 11.222222
# 3542073           168               36                 10.601227
# 7755686            88                4                 10.000000
# 1118365            29                1                 13.333333
# 313403              5                1                 19.000000
# 263566             17                1                 14.000000
# 9038291            74                5                 20.000000
# 2512641            79                3                  6.333333
# 9008706           419                6                  9.875000
# 6531025             1                1                 23.000000
# 7893752            46                1                  8.222222
# 3262011            88                2                 16.250000
# 3846366             7                2                 23.000000
# 450230              6                1                 17.500000
# 8919934            45                1                 23.000000
# 1978490            11                1                 23.000000
# 2620890           109               25                  9.826923
# 5116481            40                2                 23.000000
#
#          ip_app_channel_h_mean_m  i_next_click  ia_next_click  ic_next_click  \
# 1344910                 0.000000       32871.0        32871.0          764.0
# 695655                  0.000000       10621.0        32811.0        26371.0
# 4127104                 0.000000       40490.0        39765.0        46731.0
# 5400380                 0.000000       63717.0        36386.0        36386.0
# 9758181                 0.000000       43136.0        43025.0        42705.0
# 5887743                 0.000000       29977.0        43025.0        42705.0
# 2150876                21.500000       81270.0        52205.0        30901.0
# 8660526                12.500000       29787.0        16048.0        85121.0
# 4467339                 0.000000       26118.0        24173.0        42705.0
# 5008883                 0.000000        4839.0        19610.0        34343.0
# 6173687                29.875000          61.0           61.0           61.0
# 8760391                27.872341       21712.0        44419.0         1278.0
# 3081752                 0.500000       50569.0           77.0           77.0
# 5404209                 0.000000       59409.0        59409.0        13863.0
# 3729169                 0.000000       12186.0        82622.0        17146.0
# 3884624                16.666666       38246.0        80204.0        22513.0
# 5616801                 0.000000       38184.0        36658.0        36658.0
# 6074861                17.000000        4589.0        52243.0         1085.0
# 2698128                 0.000000       55019.0        50062.0        27915.0
# 8574959                17.533333       68013.0        51580.0        51580.0
# 2721879                19.166666       38599.0        42056.0        42056.0
# 8009822                 0.000000       42897.0         7248.0        39786.0
# 2659099                 0.000000       16934.0        27616.0        59062.0
# 1378087                 0.000000        5842.0         5842.0        14402.0
# 4548284                27.500000       30883.0        36219.0         3332.0
# 3301348                 0.000000        1693.0         4736.0        46659.0
# 332957                 21.272728       47848.0        43346.0        43346.0
# 6962398                10.000000       54060.0          480.0          480.0
# 412005                  0.000000        5393.0        57301.0        36180.0
# 8742481                22.600000        7759.0        71005.0        71005.0
# ...                          ...           ...            ...            ...
# 3680672                59.000000       16283.0        51267.0        51267.0
# 2231593                59.000000        5978.0         5978.0        35715.0
# 9846680                59.000000       10542.0        43025.0        42705.0
# 6950729                47.000000       27694.0        18614.0        17376.0
# 6475885                43.000000        7521.0        82425.0        22975.0
# 5205272                59.000000       43624.0        43025.0         1675.0
# 4226622                59.000000       32013.0        33609.0        42705.0
# 7827763                59.000000       54952.0        24778.0        24778.0
# 4503575                59.000000       61881.0        43025.0        55575.0
# 5322252                59.000000       84208.0        43025.0        42705.0
# 7244452                59.000000       19024.0        45958.0        25660.0
# 9223825                59.000000       39107.0        43025.0         2743.0
# 4222520                59.000000       50579.0        63113.0        58123.0
# 3542073                27.000000       54947.0        47438.0        47438.0
# 7755686                59.000000       25527.0        62123.0        40312.0
# 1118365                59.000000        4236.0         8447.0        58567.0
# 313403                 58.500000       45913.0        40878.0        40878.0
# 263566                 59.000000       42599.0         1988.0        18564.0
# 9038291                57.500000        3274.0        36861.0        52423.0
# 2512641                59.000000       26278.0        43928.0         7195.0
# 9008706                41.500000       61777.0        40063.0        53559.0
# 6531025                59.000000       27236.0        43025.0        42991.0
# 7893752                59.000000       16223.0         4833.0        39503.0
# 3262011                43.500000       80532.0        34317.0        23159.0
# 3846366                59.000000       59599.0         1905.0        37443.0
# 450230                 46.666668        4538.0         4538.0         4538.0
# 8919934                59.000000       18888.0        60642.0        42705.0
# 1978490                59.000000       84836.0        25194.0        42705.0
# 2620890                37.250000       30306.0        83289.0        19873.0
# 5116481                59.000000       38987.0        57767.0        42705.0
#
#          io_next_click  iod_next_click  ip_app_os_skew_h_std
# 1344910        28761.0         28761.0                 0.439
# 695655         52827.0         52827.0                 0.439
# 4127104        42520.0         42477.0                 0.439
# 5400380          342.0           342.0                 0.439
# 9758181        42520.0         42477.0                 0.439
# 5887743        80615.0         80615.0                 0.434
# 2150876        13784.0         13784.0                 0.203
# 8660526        85243.0         85243.0                 0.207
# 4467339        42520.0         42477.0                 0.288
# 5008883        18923.0         18923.0                 0.287
# 6173687           61.0            61.0                 0.444
# 8760391        47916.0         47916.0                 0.466
# 3081752        42189.0         42189.0                 0.467
# 5404209        16938.0         16938.0                 0.425
# 3729169        31312.0         31312.0                 0.445
# 3884624        38246.0         38246.0                 0.318
# 5616801        23635.0         23635.0                 0.319
# 6074861        19155.0         19155.0                 0.282
# 2698128        48454.0         50062.0                 0.377
# 8574959         1052.0          1052.0                 1.152
# 2721879        51268.0         82053.0                 1.191
# 8009822        51714.0         51714.0                 1.456
# 2659099         7405.0          7405.0                 1.457
# 1378087        23391.0         23391.0                 1.517
# 4548284        85783.0         85783.0                 1.008
# 3301348         1693.0          1693.0                 1.005
# 332957         49643.0         49643.0                 0.590
# 6962398         1837.0          1837.0                 0.550
# 412005         80162.0         80162.0                 0.640
# 8742481         7759.0          7759.0                 0.643
# ...                ...             ...                   ...
# 3680672         9306.0          9306.0                 0.919
# 2231593        59121.0         59121.0                 0.830
# 9846680        42520.0         42477.0                 0.621
# 6950729        85740.0         85740.0                 0.644
# 6475885        66481.0         66481.0                 0.702
# 5205272        62370.0         62370.0                 0.610
# 4226622        33609.0         42477.0                 0.606
# 7827763        30000.0         30000.0                 0.607
# 4503575        61881.0         61881.0                 0.299
# 5322252        42520.0         42477.0                 0.095
# 7244452        31724.0         31724.0                 0.180
# 9223825        10506.0         10506.0                 0.177
# 4222520        49735.0         49735.0                 0.290
# 3542073        40025.0         40025.0                 0.295
# 7755686        16222.0         16222.0                 0.663
# 1118365        54437.0         54437.0                 0.684
# 313403         27882.0         27882.0                 0.709
# 263566         23112.0         23112.0                 0.680
# 9038291        29044.0         29044.0                 0.674
# 2512641        28152.0         28152.0                 0.339
# 9008706        44370.0         44370.0                 0.456
# 6531025        23688.0         23688.0                 0.465
# 7893752        42520.0         42477.0                 0.458
# 3262011        69245.0         69245.0                 0.451
# 3846366         1905.0          1905.0                 0.404
# 450230         42520.0         42477.0                 0.190
# 8919934        35985.0         35985.0                 0.100
# 1978490        42520.0         42477.0                 0.046
# 2620890        83782.0         83782.0                 0.186
# 5116481        10362.0         10362.0                 0.189
#
# [10000000 rows x 34 columns]
